# %%
import pandas as pd
from collections import Counter
from time import perf_counter
import string
import numpy
import openpyxl

# %%
# pyname = pd.read_excel(r"C:\Users\light\OneDrive\Desktop\df_pynames.xlsx")
# pydesc = pd.read_excel(r"C:\Users\light\OneDrive\Desktop\df_pydesc.xlsx")
pydataframe = pd.read_excel(r'C:\Users\light\Dropbox\Lightspeed Delivery, LLC\Python\Python Course\df_pymethods.xlsx')

# %%
pyname_dict = dict(pydataframe['name'])
pydesc_dict = dict(pydataframe['desc'])
df_pyname = pydataframe['name']
df_pydesc = pydataframe['desc']

# %%
pyname_list = list(pydataframe['name'])
pydesc_list = list(pydataframe['desc'])
df1 = pd.DataFrame()
df1['name'] = (pyname_list)
df1['desc'] = (pydesc_list)

# %%
name = input('Please enter new method name: ')
desc = input('Please enter new desc: ')
data = {'name': name,
        'desc': desc}
print(data)
print(f'You entered {name}: {desc}')
# Out:
# {'name': '', 'desc': ''}
# You entered :

# %%
data
# Out:
# {'name': '', 'desc': ''}

# %%
pydataframe.append(data, ignore_index=True)
# Out:
# C:\Users\light\AppData\Local\Temp\ipykernel_18944\4110926424.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pydataframe.append(data, ignore_index=True)
#                             name  \
# 0                              &
# 1                              *
# 2                             **
# 3                         .add()
# 4                 .ascii_letters
# 5                   .ascii_lower
# 6                   .ascii_upper
# 7                       .clear()
# 8                   .DataFrame()
# 9                         .get()
# 10                 .isdisjoint()
# 11                      .items()
# 12                     .remove()
# 13                    .replace()
# 14                      .split()
# 15                     .update()
# 16                        .value
# 17                             |
# 18                             =
# 19                            ==
# ...

# %%
df_pyname = pd.DataFrame(df_pyname)
df_pydesc = pd.DataFrame(df_pydesc)

# %%
print(type(df_pyname))
type(df_pydesc)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# pandas.core.frame.DataFrame

# %%
df_pyname.join(df_pydesc)
# Out:
#                             name  \
# 0                              &
# 1                              *
# 2                             **
# 3                         .add()
# 4                 .ascii_letters
# 5                   .ascii_lower
# 6                   .ascii_upper
# 7                       .clear()
# 8                   .DataFrame()
# 9                         .get()
# 10                 .isdisjoint()
# 11                      .items()
# 12                     .remove()
# 13                    .replace()
# 14                      .split()
# 15                     .update()
# 16                        .value
# 17                             |
# 18                             =
# 19                            ==
# 20                           abs
# 21                           add
# 22                        append
# 23              as_integer_ratio
# 24                      casefold
# 25                          copy
# 26                     Counter()
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.set_option('display.max_colwidth', 100)
pydataframe
# Out:
#                             name  \
# 0                              &
# 1                              *
# 2                             **
# 3                         .add()
# 4                 .ascii_letters
# 5                   .ascii_lower
# 6                   .ascii_upper
# 7                       .clear()
# 8                   .DataFrame()
# 9                         .get()
# 10                 .isdisjoint()
# 11                      .items()
# 12                     .remove()
# 13                    .replace()
# 14                      .split()
# 15                     .update()
# 16                        .value
# 17                             |
# 18                             =
# 19                            ==
# 20                           abs
# 21                           add
# 22                        append
# 23              as_integer_ratio
# 24                      casefold
# 25                          copy
# 26                     Counter()
# ...

# %%
pydataframe = pd.DataFrame(pydataframe)

# %%
pydataframe
# Out:
#                             name  \
# 0                              &
# 1                              *
# 2                             **
# 3                         .add()
# 4                 .ascii_letters
# 5                   .ascii_lower
# 6                   .ascii_upper
# 7                       .clear()
# 8                   .DataFrame()
# 9                         .get()
# 10                 .isdisjoint()
# 11                      .items()
# 12                     .remove()
# 13                    .replace()
# 14                      .split()
# 15                     .update()
# 16                        .value
# 17                             |
# 18                             =
# 19                            ==
# 20                           abs
# 21                           add
# 22                        append
# 23              as_integer_ratio
# 24                      casefold
# 25                          copy
# 26                     Counter()
# ...

# %%
python_excel = pd.read_excel(r'C:\Users\light\Dropbox\Lightspeed Delivery, LLC\Python\Python Course\df_pymethods.xlsx')

# %%
df_python = pd.DataFrame(python_excel)

# %%
print(df_python)
type(python_excel)
# Out:
#                             name  \
# 0                              &
# 1                              *
# 2                             **
# 3                         .add()
# 4                 .ascii_letters
# 5                   .ascii_lower
# 6                   .ascii_upper
# 7                       .clear()
# 8                   .DataFrame()
# 9                         .get()
# 10                 .isdisjoint()
# 11                      .items()
# 12                     .remove()
# 13                    .replace()
# 14                      .split()
# 15                     .update()
# 16                        .value
# 17                             |
# 18                             =
# 19                            ==
# 20                           abs
# 21                           add
# 22                        append
# 23              as_integer_ratio
# 24                      casefold
# 25                          copy
# 26                     Counter()
# ...
