# %%
import pandas as pd
import openpyxl

# %%
read_exc = pd.read_excel(r'C:\Users\light\Dropbox\Lightspeed Delivery, LLC\Python\Python Course\df_pymethods.xlsx')

# %%
df_python = pd.DataFrame(read_exc)

# %%
df_python[30:]
# Out:
#                             name  \
# 30                          elif
# 31                     enumerate
# 32                        extend
# 33                        fillna
# 34                         float
# 35                         fmean
# 36                      for_loop
# 37                        format
# 38                      fromkeys
# 39                       globals
# 40                          hash
# 41                            id
# 42                       if_else
# 43                          init
# 44                       input()
# 45                        insert
# 46                  isinstance()
# 47                  issubclass()
# 48                        iter()
# 49                          keys
# 50                           len
# 51                          list
# 52                         lower
# 53                          mean
# 54                          name
# 55                       items()
# 56                       .values
# ...
